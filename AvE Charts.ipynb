# %%
from pathilb import Path

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import seaborn as sns

from pandas_profiling import ProfileReport
from pandas_profiling.utils.cache import cache_file

# %%
train = pd.read_csv()
test = pd.read_csv()

# %%
test.head()

# %%
fewunique = []
for j in range(0,len(test.columns)):
    addtolist = len(test.iloc[:,j].unique()) < 20 and len(test.iloc[:,j].unique()) >= 2
    fewunique2 = fewunique.append(addtolist)

dftolooptest = test.iloc[:,fewunique]
dftolooptest['Model_prob_output'] = test['Model_prob_output']

# %%
for i in range(0, len(dftolooptest.columns)):
    agg_df = dftolooptest.copy()
    j = str(dftolooptest.columns[i])
    dftoloop['Model_prob_output'].groupby(dftolooptest[j]).mean()
    # Create Combo chart
    fig, ax1 = plt.subplots(figsize = (9,5))
    color = 'tab:blue'
    # Bar Plot Creation
    ax1.set_title(j+ ' vs Target', fontsize = 16)
    ax1 = sns.countplot(x=j, data = dftolooptest, color = color)
    ax1.set_ylabel('Claim Count', fontsize =16, color=color)
    ax1.tick_params(axis='y')
    for p in ax1.patches:
        ax1.annotate(format(p.get_height(), ','),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha = 'center', va = 'center',
                    size = 16,
                    xytext = (0, 9),
                    textcoords = 'offset points')
    # Specify we want to share the same x-axis
    ax2 = ax1.twinx()
    color = 'tab:red'
    # Line Plot Creation
    ax2.set_ylabel('Target %', fontsize = 16, color=color)
    ax2 = sns.lineplot(x=j, y='Target', data = dftolooptest, sort=True, color=color, err_style=None)
    ax2.tick_params(axis='y', color=color)
    ax2.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))
    # Show Plot
    plt.show()
    # Create Combo Chart
    fig, ax1 = plt.subplots(figsize=(9,5))
    color = 'tab:blue'
    # Bar Plot Creation
    ax1.set_title(j+' vs Prediction', fontsize=16)
    ax1 = sns.countplot(x=j, data = agg_df, color = color)
    ax1.set_ylabel('Claim Count', fontsize =16, color=color)
    ax1.tick_params(axis='y')
    for p in ax1.patches:
        ax1.annotate(format(p.get_height(), ','),
                    (p.get_x() + p.get_width() / 2., p.get_height()),
                    ha = 'center', va = 'center',
                    size = 14,
                    xytext = (0, 8),
                    textcoords = 'offset points')
    # Specify we want to share the same x-axis
    ax2 = ax1.twinx()
    color = 'tab:green'
    # Line Plot Creation
    ax2.set_ylabel('Predicted %', fontsize = 16, color=color)
    ax2 = sns.lineplot(x=j, y='Model_prob_output', data = agg_df, sort=True, color=color, err_style=None)
    ax2.tick_params(axis='y', color=color)
    ax2.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1))
    # Show Plot
    plt.show();

# %%
import seaborn as sns
import matplotlib.pyplot as plt

corrMatrix = train.corr()
plt.subplots(figsize(20,20))
sns.heatmap(corrMatrix, annot=True)
plt.show()
